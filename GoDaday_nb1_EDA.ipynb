# %% [markdown]
# <a href="https://colab.research.google.com/github/mohmaed7777/GoDaddy---Microbusiness-Density-Forecasting/blob/main/GoDaday_nb1_EDA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install kaggle
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
# !mkdir ~/.kaggle

# %%
! cp kaggle.json ~/.kaggle/

# %%
! chmod 600 ~/.kaggle/kaggle.json

# %%
! kaggle competitions download -c godaddy-microbusiness-density-forecasting
# Out:
# ...
# 100% 1.74M/1.74M [00:00<00:00, 2.57MB/s]
# 100% 1.74M/1.74M [00:00<00:00, 2.29MB/s]

# %%
! unzip godaddy-microbusiness-density-forecasting.zip
# Out:
# Archive:  godaddy-microbusiness-density-forecasting.zip
#   inflating: census_starter.csv
#   inflating: sample_submission.csv
#   inflating: test.csv
#   inflating: train.csv

# %% [markdown]
# # **EDA:=**

# %%
# !pip install yfinance
# !pip install ta
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.2/59.2 KB 2.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 112.2/112.2 KB 6.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 111.0/111.0 KB 13.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.8/62.8 KB 7.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 129.4/129.4 KB 14.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.2/4.2 MB 41.5 MB/s eta 0:00:00
# ...
#   Attempting uninstall: requests
#     Found existing installation: requests 2.25.1
#     Uninstalling requests-2.25.1:
#       Successfully uninstalled requests-2.25.1
#   Attempting uninstall: html5lib
#     Found existing installation: html5lib 1.0.1
#     Uninstalling html5lib-1.0.1:
#       Successfully uninstalled html5lib-1.0.1
#   Attempting uninstall: beautifulsoup4
# ...

# %%
import matplotlib.pyplot as plt
import matplotlib.style 
plt.style.use('ggplot')
import plotly.graph_objects as go 
from plotly.subplots import make_subplots
import numpy as np 
import pandas as pd 
import yfinance as yf 
from ta.trend import SMAIndicator
print('ready to go!!')
# Out:
# ready to go!!

# %%
df_sample_sub = pd.read_csv('/content/sample_submission.csv')
df_sample_sub.head()
# Out:
#             row_id  microbusiness_density
# 0  1001_2022-11-01               3.817671
# 1  1003_2022-11-01               3.817671
# 2  1005_2022-11-01               3.817671
# 3  1007_2022-11-01               3.817671
# 4  1009_2022-11-01               3.817671

# %%
df_sample_sub.tail()
# Out:
#                  row_id  microbusiness_density
# 25075  56037_2023-06-01               3.817671
# 25076  56039_2023-06-01               3.817671
# 25077  56041_2023-06-01               3.817671
# 25078  56043_2023-06-01               3.817671
# 25079  56045_2023-06-01               3.817671

# %%
df_census = pd.read_csv('/content/census_starter.csv')
df_census.head()
# Out:
#    pct_bb_2017  pct_bb_2018  ...  median_hh_inc_2020  median_hh_inc_2021
# 0         76.6         78.9  ...             57982.0             62660.0
# 1         74.5         78.1  ...             61756.0             64346.0
# 2         57.2         60.4  ...             34990.0             36422.0
# 3         62.0         66.1  ...             51721.0             54277.0
# 4         65.8         68.5  ...             48922.0             52830.0
#
# [5 rows x 26 columns]

# %%
df_train = pd.read_csv('/content/train.csv')
df_train.head()
# Out:
#             row_id  cfips  ... microbusiness_density active
# 0  1001_2019-08-01   1001  ...              3.007682   1249
# 1  1001_2019-09-01   1001  ...              2.884870   1198
# 2  1001_2019-10-01   1001  ...              3.055843   1269
# 3  1001_2019-11-01   1001  ...              2.993233   1243
# 4  1001_2019-12-01   1001  ...              2.993233   1243
#
# [5 rows x 7 columns]

# %%
df_train.tail()
# Out:
#                   row_id  cfips  ... microbusiness_density active
# 122260  56045_2022-06-01  56045  ...              1.803249    101
# 122261  56045_2022-07-01  56045  ...              1.803249    101
# 122262  56045_2022-08-01  56045  ...              1.785395    100
# 122263  56045_2022-09-01  56045  ...              1.785395    100
# 122264  56045_2022-10-01  56045  ...              1.785395    100
#
# [5 rows x 7 columns]

# %%
df_test = pd.read_csv('/content/test.csv')
df_test.head()
# Out:
#             row_id  cfips first_day_of_month
# 0  1001_2022-11-01   1001         2022-11-01
# 1  1003_2022-11-01   1003         2022-11-01
# 2  1005_2022-11-01   1005         2022-11-01
# 3  1007_2022-11-01   1007         2022-11-01
# 4  1009_2022-11-01   1009         2022-11-01

# %%
df_train.shape
# Out:
# (122265, 7)

# %%
df_train.isna().sum()
# Out:
# row_id                   0
# cfips                    0
# county                   0
# state                    0
# first_day_of_month       0
# microbusiness_density    0
# active                   0
# dtype: int64

# %%
df_train.columns
# Out:
# Index(['row_id', 'cfips', 'county', 'state', 'first_day_of_month',
#        'microbusiness_density', 'active'],
#       dtype='object')

# %%
df_train.columns = ['row_id', 'cfips', 'county', 'state', 'Date','microbusiness_density', 'active']
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-31-3ad1bd8fbe33> in <module>
# ----> 1 df_train.columns = ['row_id', 'cfips', 'county', 'state', 'Date','microbusiness_density', 'active']
#
# /usr/local/lib/python3.8/dist-packages/pandas/core/generic.py in __setattr__(self, name, value)
#    5498         try:
#    5499             object.__getattribute__(self, name)
# -> 5500             return object.__setattr__(self, name, value)
#    5501         except AttributeError:
#    5502             pass
#
# /usr/local/lib/python3.8/dist-packages/pandas/_libs/properties.pyx in pandas._libs.properties.AxisProperty.__set__()
#
# /usr/local/lib/python3.8/dist-packages/pandas/core/generic.py in _set_axis(self, axis, labels)
#     764     def _set_axis(self, axis: int, labels: Index) -> None:
#     765         labels = ensure_index(labels)
# ...

# %%
df_train.set_index('Date', drop=True, inplace=True)

# %%
df_max_values_show = df_train[df_train['state'] == df_train['state'].max()]
df_max_values_show.head()
# Out:
#                       row_id  cfips  ... microbusiness active
# Date                                 ...
# 2019-08-01  56001_2019-08-01  56001  ...      4.418531   1402
# 2019-09-01  56001_2019-09-01  56001  ...      4.645446   1474
# 2019-10-01  56001_2019-10-01  56001  ...      4.607627   1462
# 2019-11-01  56001_2019-11-01  56001  ...      4.736842   1503
# 2019-12-01  56001_2019-12-01  56001  ...      4.815632   1528
#
# [5 rows x 6 columns]

# %%
df_max_mbusi_show = df_train[df_train['microbusiness'] == df_train['microbusiness'].max()]
df_max_mbusi_show.head()
# Out:
#                       row_id  cfips  ... microbusiness active
# Date                                 ...
# 2019-10-01  46127_2019-10-01  46127  ...     284.34003  32011
#
# [1 rows x 6 columns]

# %%
df_train[df_train['state'] == df_train['state'].max()]
# Out:
#                       row_id  cfips  ... microbusiness active
# Date                                 ...
# 2019-08-01  56001_2019-08-01  56001  ...      4.418531   1402
# 2019-09-01  56001_2019-09-01  56001  ...      4.645446   1474
# 2019-10-01  56001_2019-10-01  56001  ...      4.607627   1462
# 2019-11-01  56001_2019-11-01  56001  ...      4.736842   1503
# 2019-12-01  56001_2019-12-01  56001  ...      4.815632   1528
# ...                      ...    ...  ...           ...    ...
# 2022-06-01  56045_2022-06-01  56045  ...      1.803249    101
# 2022-07-01  56045_2022-07-01  56045  ...      1.803249    101
# 2022-08-01  56045_2022-08-01  56045  ...      1.785395    100
# 2022-09-01  56045_2022-09-01  56045  ...      1.785395    100
# 2022-10-01  56045_2022-10-01  56045  ...      1.785395    100
#
# [897 rows x 6 columns]

# %%
df_train[df_train['state'] == df_train['state'].min()]
# Out:
#                      row_id  cfips  ... microbusiness active
# Date                                ...
# 2019-08-01  1001_2019-08-01   1001  ...      3.007682   1249
# 2019-09-01  1001_2019-09-01   1001  ...      2.884870   1198
# 2019-10-01  1001_2019-10-01   1001  ...      3.055843   1269
# 2019-11-01  1001_2019-11-01   1001  ...      2.993233   1243
# 2019-12-01  1001_2019-12-01   1001  ...      2.993233   1243
# ...                     ...    ...  ...           ...    ...
# 2022-06-01  1133_2022-06-01   1133  ...      1.234502    233
# 2022-07-01  1133_2022-07-01   1133  ...      2.463707    465
# 2022-08-01  1133_2022-08-01   1133  ...      3.947229    745
# 2022-09-01  1133_2022-09-01   1133  ...      3.597542    679
# 2022-10-01  1133_2022-10-01   1133  ...      3.555155    671
#
# [2613 rows x 6 columns]

# %%
title = 'South Dakota'
df_train[df_train['state']==title][['microbusiness_density']].plot(figsize=(12,5),title=title,fontsize=15)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-30-ae557bdaf193> in <module>
#       1 title = 'South Dakota'
# ----> 2 df_train[df_train['state']==title][['microbusiness_density']].plot(figsize=(12,5),title=title,fontsize=15)
#
# /usr/local/lib/python3.8/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    3462             if is_iterator(key):
#    3463                 key = list(key)
# -> 3464             indexer = self.loc._get_listlike_indexer(key, axis=1)[1]
#    3465
#    3466         # take() does not accept boolean indexers
#
# /usr/local/lib/python3.8/dist-packages/pandas/core/indexing.py in _get_listlike_indexer(self, key, axis)
#    1312             keyarr, indexer, new_indexer = ax._reindex_non_unique(keyarr)
#    1313
# -> 1314         self._validate_read_indexer(keyarr, indexer, axis)
#    1315
# ...
